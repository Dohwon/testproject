# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
user = pd.read_csv('intent_userSentence.csv',encoding = "utf-8")
user.head()
# Out:
#         intentName             categoryName intentType  \
# 0       건설기술용역업 안내  01. 일반공공행정-1) 건설지원과(행정)   STANDARD
# 1         행정 심판 안내      01. 일반공공행정-2) 법무담당관   STANDARD
# 2  신문사업/인터넷신문사업 안내      01. 일반공공행정-3) 소통기획관   STANDARD
# 3    인터넷뉴스서비스사업 안내      01. 일반공공행정-3) 소통기획관   STANDARD
# 4     참고자료 등록제호 안내      01. 일반공공행정-3) 소통기획관   STANDARD
#
#                                        UserSentences  \
# 0  건설기술용역업 변경등록 신청하고 싶어요#@#건설기술용역업;건설기술용역업;0;6#&#...
# 1  행정 심판 청구 신청하고 싶어요#@#행정심판;행정 심판;0;4#&#신청;청구;6;7...
# 2  신문사업/인터넷신문사업 변경등록 신청하고 싶어요#@#신문;신문;0;1#&#사업;사업...
# 3  인터넷뉴스서비스사업 등록 신청하고 싶어요#@#인터넷뉴스서비스;인터넷뉴스서비스;0;7...
# 4  참고자료 등록제호 검색 주소 알고싶어요#@#자료;참고자료;0;3#&#등록제호;등록제...
#
#                                           Unnamed: 4  \
# 0  건설기술용역업 폐업 신청하고 싶어요#@#건설기술용역업;건설기술용역업;0;6#&#휴업...
# 1  행정 심판 관련 민원을 신청하고 싶어요#@#행정심판;행정 심판;0;4#&#관련;관련...
# 2  신문사업/인터넷신문사업 등록 신청하고 싶어요#@#신문;신문;0;1#&#사업;사업;2...
# 3  인터넷뉴스서비스사업 변경등록 신청하고 싶어요#@#인터넷뉴스서비스;인터넷뉴스서비스;0...
# ...

# %%
df = pd.DataFrame(user)
df = df.drop(['categoryName','intentType'], axis=1)
df
# Out:
#                   intentName  \
# 0                 건설기술용역업 안내
# 1                   행정 심판 안내
# 2            신문사업/인터넷신문사업 안내
# 3              인터넷뉴스서비스사업 안내
# 4               참고자료 등록제호 안내
# ..                       ...
# 155                  일상대화_날씨
# 156                   코로나 안내
# 157                     여권발급
# 158  Default_Fallback_Intent
# 159  Default_Greeting_Intent
#
#                                          UserSentences  \
# 0    건설기술용역업 변경등록 신청하고 싶어요#@#건설기술용역업;건설기술용역업;0;6#&#...
# 1    행정 심판 청구 신청하고 싶어요#@#행정심판;행정 심판;0;4#&#신청;청구;6;7...
# 2    신문사업/인터넷신문사업 변경등록 신청하고 싶어요#@#신문;신문;0;1#&#사업;사업...
# 3    인터넷뉴스서비스사업 등록 신청하고 싶어요#@#인터넷뉴스서비스;인터넷뉴스서비스;0;7...
# 4    참고자료 등록제호 검색 주소 알고싶어요#@#자료;참고자료;0;3#&#등록제호;등록제...
# ..                                                 ...
# 155             날씨 정보가 궁금해요#@#일상대화_날씨;날씨 정보가 궁금해요;0;10
# 156                                  코로나#@#코로나;코로나;0;2
# 157                   여권 발급 문의#@#여권;여권;0;1#&#발급;발급;3;4
# ...

# %%
df1 = pd.melt(df, id_vars=['intentName'], value_vars=None)   #id_vars=['대분류','중분류','소분류','인텐트명']
df1.head(10)
# Out:
#            intentName       variable  \
# 0          건설기술용역업 안내  UserSentences
# 1            행정 심판 안내  UserSentences
# 2     신문사업/인터넷신문사업 안내  UserSentences
# 3       인터넷뉴스서비스사업 안내  UserSentences
# 4        참고자료 등록제호 안내  UserSentences
# 5      비영리민간단체(여성) 안내  UserSentences
# 6  경상남도학교폭력대책지역위원회 안내  UserSentences
# 7           다단계판매업 안내  UserSentences
# 8        선불식 할부거래업 안내  UserSentences
# 9          후원방문판매업 안내  UserSentences
#
#                                                value
# 0  건설기술용역업 변경등록 신청하고 싶어요#@#건설기술용역업;건설기술용역업;0;6#&