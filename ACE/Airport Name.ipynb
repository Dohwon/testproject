# %%
import pandas as pd
import numpy as np

# %%
Airport = pd.read_csv('ACE_공항명.csv',header=None, encoding = 'UTF-8')

# %%
airport = []

for i in Airport[1]:
    air = str(i).split('공항')[0]
    airport.append(air.split('국제')[0])
airport
# Out:
# ['인천 ',
#  '김포 ',
#  '김해 ',
#  '제주 ',
#  '대구 ',
#  '청주 ',
#  '광주 ',
#  '무안 ',
#  '양양 ',
#  '울산 ',
#  '사천 ',
#  '포항 ',
#  '군산 ',
#  '여수 ',
#  '목포 ',
#  '원주 ',
#  '서울 ',
#  '정석 ',
#  '애들레이드 ',
#  '올버니 ',
#  '엘버리 ',
#  '앨리스 스프링스 ',
#  '알파 ',
#  '알리앵굴라 ',
#  '아라라트 ',
#  '아미데일 ',
#  '아발론 ',
#  '반즈데일 ',
#  '밸리나 바이런 게이트웨이 ',
#  '발라놀드 ',
#  '뱅크스타운 ',
#  '바르칼딘 ',
#  '베더스트아일랜드 ',
#  '베두리 ',
#  '벨먼트 ',
#  '베날라 ',
#  '벤디고 ',
#  '버드스빌 ',
#  '블랙올 ',
#  '블랙워터 ',
#  '부리아 ',
#  '부케 ',
#  '브레와리나 ',
#  '브리즈번 ',
#  '브로큰힐 ',
#  '브룸 ',
#  '번다버그 ',
#  '버니 윈야드 ',
#  '부셀톤 지역',
#  '케언스 ',
#  '캠던 ',
#  '캔버라 ',
#  '카나번 ',
#  '세두나 ',
#  '샤를빌 ',
#  '친칠라 ',
#  '크리스마스아일랜드 ',
#  '클레르몽 ',
#  '크레브 ',
#  '클론커리 ',
#  '코바 ',
#  '코코스 킬링 아일랜드 ',
#  '코언 ',
#  '코프스하버 ',
#  '콜라레네브리 ',
#  '코넬런 ',
#  '쿠버페디 ',
#  '쿡타운 ',
#  '쿨랑가타 ',
#  '쿠마 수노이 ',
#  '쿠나바라브란 ',
#  '쿠남블 ',
#  '쿠타문드라 ',
#  '코로와 ',
#  '코리용 ',
#  '코우라 ',
#  '크로커아일랜드 ',
#  '큐 ',
#  '쿠나물라 ',
#  '커튼 ',
#  '다윈 ',
#  '데닐리킨 ',
#  '더비 ',
#  '데번포트 ',
#  '디란반디 ',
#  '두보 ',
# ...

# %%
Airport['name'] = airport
Airport
# Out:
#              0                 1    2    3    4   5            name
# 0     ICN|항공코드           인천 국제공항  NaN  NaN  NaN NaN             인천
# 1     GMP|항공코드           김포 국제공항  NaN  NaN  NaN NaN             김포
# 2     PUS|항공코드           김해 국제공항  NaN  NaN  NaN NaN             김해
# 3     CJU|항공코드           제주 국제공항  NaN  NaN  NaN NaN             제주
# 4     TAE|항공코드           대구 국제공항  NaN  NaN  NaN NaN             대구
# 5     CJJ|항공코드           청주 국제공항  NaN  NaN  NaN NaN             청주
# 6     KWJ|항공코드           광주 국제공항  NaN  NaN  NaN NaN             광주
# 7     MWX|항공코드           무안 국제공항  NaN  NaN  NaN NaN             무안
# 8     YNY|항공코드           양양 국제공항  NaN  NaN  NaN NaN             양양
# 9     USN|항공코드             울산 공항  NaN  NaN  NaN NaN             울산
# 10    HIN|항공코드             사천 공항  NaN  NaN  NaN NaN             사천
# 11    KPO|항공코드             포항 공항  NaN  NaN  NaN NaN             포항
# 12    KUV|항공코드             군산 공항  NaN  NaN  NaN NaN             군산
# ...

# %%
Airport.to_csv('Airportname.csv', header = None, encoding = 'UTF-8')

# %%
AirDeparture = ['출발','에서 출발','에서 온','공항 출발','공항출발','공항에서 출발','공항에서 온','국제 공항 출발','국제 공항출발','국제 공항에서 출발','국제 공항에서 온','국제공항 출발','국제공항출발','국제공항에서 출발','국제공항에서 온']

# %%
# 인자를 몇개나 할건가아아아 
AirArrival = ['에서 도착','도착','으로 가는','로 가는','로 도착',' 행','행','으로 간','에 도착',' 도착','으로 도착']

# %%
AirArrival1 = ['공항에서 도착','공항도착','공항으로 가는','공항행','공항으로 간','공항에 도착','공항 도착','공항으로 도착','공항 행']

# %%
AirArrival2 = ['국제공항에서 도착','국제공항도착','국제공항으로 가는','국제공항행','국제공항으로 간','국제공항에 도착','국제공항 도착','국제공항으로 도착']

# %%
AirArrival3 = ['국제 공항에서 도착','국제 공항도착','국제 공항으로 가는','국제 공항행','국제 공항으로 간','국제 공항에 도착','국제 공항 도착','국제 공항으로 도착']

# %%
AirArrival0 = ['에서 도착','도착','으로 가는','로 가는','로 도착',' 행','행','으로 간','에 도착',' 도착','으로 도착','공항에서 도착','공항도착','공항으로 가는','공항행','공항으로 간','공항에 도착','공항 도착','공항으로 도착','공항 행','국제공항에서 도착','국제공항도착','국제공항으로 가는','국제공항행','국제공항으로 간','국제공항에 도착','국제공항 도착','국제공항으로 도착','국제 공항에서 도착','국제 공항도착','국제 공항으로 가는','국제 공항행','국제 공항으로 간','국제 공항에 도착','국제 공항 도착','국제 공항으로 도착']

# %%
Airport = pd.read_csv('ACE_공항명수정.csv',header=None, encoding = 'UTF-8')

# %%
len(AirArrival0)
# Out:
# 36

# %%
bb = []
for j in range(5820):
    a = []
    for i in range(2,5):
        a.append(Airport[i][j])
    bb.append(a)

# %%
airportname = []

for l in range(5820):
    b = []
    for i in bb[l]: 
        for k in range(15):
            if str(i) != 'nan':
                b.append(str(i)+str(AirDeparture[k]))
            else:
                b.append('nan')
    airportname.append(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-bc00a6dcf9ad> in <module>
#       6         for k in range(15):
#       7             if str(i) != 'nan':
# ----> 8                 b.append(str(i)+str(AirDeparture[k]))
#       9             else:
#      10                 b.append('nan')
#
# NameError: name 'AirDeparture' is not defined

# %%
airportname0 = []

for l in range(5820):
    b = []
    for i in bb[l]: 
        for k in range(len(AirArrival0)):
            if str(i) != 'nan':
                b.append(str(i)+str(AirArrival0[k]))
            else:
                b.append('nan')
    airportname0.append(b)

# %%
airportname1 = []

for l in range(5820):
    b = []
    for i in bb[l]: 
        for k in range(len(AirArrival1)):
            if str(i) != 'nan':
                b.append(str(i)+str(AirArrival1[k]))
            else:
                b.append('nan')
    airportname1.append(b)

# %%
airportname2 = []

for l in range(5820):
    b = []
    for i in bb[l]: 
        for k in range(len(AirArrival2)):
            if str(i) != 'nan':
                b.append(str(i)+str(AirArrival2[k]))
            else:
                b.append('nan')
    airportname2.append(b)

# %%
airportname3 = []

for l in range(5820):
    b = []
    for i in bb[l]: 
        for k in range(len(AirArrival3)):
            if str(i) != 'nan':
                b.append(str(i)+str(AirArrival3[k]))
            else:
                b.append('nan')
    airportname3.append(b)

# %%
Airportrename0 = pd.DataFrame(airportname0)
Airportrename0
# Out:
#                       0                 1                    2    \
# 0                인천 에서 도착             인천 도착             인천 으로 가는
# 1                김포 에서 도착             김포 도착             김포 으로 가는
# 2                김해 에서 도착             김해 도착             김해 으로 가는
# 3                제주 에서 도착             제주 도착             제주 으로 가는
# 4                대구 에서 도착             대구 도착             대구 으로 가는
# 5                청주 에서 도착             청주 도착             청주 으로 가는
# 6                광주 에서 도착             광주 도착             광주 으로 가는
# 7                무안 에서 도착             무안 도착             무안 으로 가는
# 8                양양 에서 도착             양양 도착             양양 으로 가는
# 9                울산 에서 도착             울산 도착             울산 으로 가는
# 10               사천 에서 도착             사천 도착             사천 으로 가는
# 11               포항 에서 도착             포항 도착             포항 으로 가는
# 12               군산 에서 도착             군산 도착             군산 으로 가는
# ...

# %%
Airportrename1 = pd.DataFrame(airportname1)
Airportrename1
# Out:
#                          0                   1                      2   \
# 0                인천 공항에서 도착             인천 공항도착             인천 공항으로 가는
# 1                김포 공항에서 도착             김포 공항도착             김포 공항으로 가는
# 2                김해 공항에서 도착             김해 공항도착             김해 공항으로 가는
# 3                제주 공항에서 도착             제주 공항도착             제주 공항으로 가는
# 4                대구 공항에서 도착             대구 공항도착             대구 공항으로 가는
# 5                청주 공항에서 도착             청주 공항도착             청주 공항으로 가는
# 6                광주 공항에서 도착             광주 공항도착             광주 공항으로 가는
# 7                무안 공항에서 도착             무안 공항도착             무안 공항으로 가는
# 8                양양 공항에서 도착             양양 공항도착             양양 공항으로 가는
# 9                울산 공항에서 도착             울산 공항도착             울산 공항으로 가는
# 10               사천 공항에서 도착             사천 공항도착             사천 공항으로 가는
# 11               포항 공항에서 도착             포항 공항도착             포항 공항으로 가는
# ...

# %%
Airportrename2 = pd.DataFrame(airportname2)
Airportrename2
# Out:
#                            0                     1                        2   \
# 0                인천 국제공항에서 도착             인천 국제공항도착             인천 국제공항으로 가는
# 1                김포 국제공항에서 도착             김포 국제공항도착             김포 국제공항으로 가는
# 2                김해 국제공항에서 도착             김해 국제공항도착             김해 국제공항으로 가는
# 3                제주 국제공항에서 도착             제주 국제공항도착             제주 국제공항으로 가는
# 4                대구 국제공항에서 도착             대구 국제공항도착             대구 국제공항으로 가는
# 5                청주 국제공항에서 도착             청주 국제공항도착             청주 국제공항으로 가는
# 6                광주 국제공항에서 도착             광주 국제공항도착             광주 국제공항으로 가는
# 7                무안 국제공항에서 도착             무안 국제공항도착             무안 국제공항으로 가는
# 8                양양 국제공항에서 도착             양양 국제공항도착             양양 국제공항으로 가는
# 9                울산 국제공항에서 도착             울산 국제공항도착             울산 국제공항으로 가는
# 10               사천 국제공항에서 도착             사천 국제공항도착             사천 국제공항으로 가는
# ...

# %%
Airportrename3 = pd.DataFrame(airportname3)
Airportrename3
# Out:
#                             0                      1   \
# 0                인천 국제 공항에서 도착             인천 국제 공항도착
# 1                김포 국제 공항에서 도착             김포 국제 공항도착
# 2                김해 국제 공항에서 도착             김해 국제 공항도착
# 3                제주 국제 공항에서 도착             제주 국제 공항도착
# 4                대구 국제 공항에서 도착             대구 국제 공항도착
# 5                청주 국제 공항에서 도착             청주 국제 공항도착
# 6                광주 국제 공항에서 도착             광주 국제 공항도착
# 7                무안 국제 공항에서 도착             무안 국제 공항도착
# 8                양양 국제 공항에서 도착             양양 국제 공항도착
# 9                울산 국제 공항에서 도착             울산 국제 공항도착
# 10               사천 국제 공항에서 도착             사천 국제 공항도착
# 11               포항 국제 공항에서 도착             포항 국제 공항도착
# 12               군산 국제 공항에서 도착             군산 국제 공항도착
# 13               여수 국제 공항에서 도착             여수 국제 공항도착
# 14               목포 국제 공항에서 도착             목포 국제 공항도착
# 15               원주 국제 공항에서 도착             원주 국제 공항도착
# ...

# %%
for i in range(len(aaa[0])):
    if str(aaa[:1][i]) == 'NaN':
        print(i)
str(aaa[:1][15])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 33
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-109-1b07fc330540> in <module>
#       1 for i in range(len(aaa[0])):
# ...

# %%
aaa[0:15][0]
# Out:
# 0     인천 에서 도착
# 1     김포 에서 도착
# 2     김해 에서 도착
# 3     제주 에서 도착
# 4     대구 에서 도착
# 5     청주 에서 도착
# 6     광주 에서 도착
# 7     무안 에서 도착
# 8     양양 에서 도착
# 9     울산 에서 도착
# 10    사천 에서 도착
# 11    포항 에서 도착
# 12    군산 에서 도착
# 13    여수 에서 도착
# 14    목포 에서 도착
# Name: 0, dtype: object

# %%
Airportrename0.to_csv('Airportrename0.csv', header = None, encoding = 'UTF-8')

# %%
aaa = pd.read_csv('Airportrename.csv',header=None, encoding = 'UTF-8')
bbb = pd.read_csv('Airportrename1.csv',header=None, encoding = 'UTF-8')
ccc = pd.read_csv('Airportrename2.csv',header=None, encoding = 'UTF-8')
ddd = pd.read_csv('Airportrename3.csv',header=None, encoding = 'UTF-8')

# %%
aaa
# Out:
#                        0                 1                    2   \
# 0                인천 에서 도착             인천 도착             인천 으로 가는
# 1                김포 에서 도착             김포 도착             김포 으로 가는
# 2                김해 에서 도착             김해 도착             김해 으로 가는
# 3                제주 에서 도착             제주 도착             제주 으로 가는
# 4                대구 에서 도착             대구 도착             대구 으로 가는
# 5                청주 에서 도착             청주 도착             청주 으로 가는
# 6                광주 에서 도착             광주 도착             광주 으로 가는
# 7                무안 에서 도착             무안 도착             무안 으로 가는
# 8                양양 에서 도착             양양 도착             양양 으로 가는
# 9                울산 에서 도착             울산 도착             울산 으로 가는
# 10               사천 에서 도착             사천 도착             사천 으로 가는
# 11               포항 에서 도착             포항 도착             포항 으로 가는
# 12               군산 에서 도착             군산 도착             군산 으로 가는
# ...
