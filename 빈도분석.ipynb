# %%
from collections import Counter
# from konlpy.tag import Kkma
import matplotlib.pyplot as pyplot
import matplotlib
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
matplotlib.rc('font',family=font_name)

# kkma = Kkma()
results = []
result = []

file = open(r'C:\Users\USER\Desktop\업무\2019_10_4_행정안전부\사용자질의문_교통안전1.txt','r',encoding='UTF-8')
lines = file.readlines()
for line in lines:
    
    results.append(line)

file.close()

sentences_tag = []
for sentence in results:
#     morph = kkma.pos(sentence)
    sentences_tag.extend(sentence.split( ))

# noun_adj_list = []
# for sentence1 in sentences_tag:
#     for word, tag in sentence1:
#         if tag in ['NNG', 'NP','VV', 'MAG']:
#             noun_adj_list.append(word)

#print(noun_adj_list)
# sum(sentences_tag,[])
sentences_tag
# Out:
# ['\ufeff횡단보도',
#  '불법',
#  '주차',
#  '"인도에',
#  '불법주차',
#  '신고입니다.(',
#  '안전신문고',
#  '앱으로',
#  '접수된',
#  '불법',
#  '주·정차',
#  '신고처리',
#  '안내',
#  ')',
#  '불법',
#  '주·정차',
#  '주민신고제',
#  '운영에',
#  '따라,',
#  '안전신문고',
#  '앱으로',
#  '접수된',
#  "'횡단보도'",
#  '불법',
#  '주·정차',
#  '과태료',
#  '부과(단속)',
#  '요청',
#  '신고입니다.',
#  '과태료',
#  '부과',
#  '후,',
#  '결과를',
#  "'수용'으로",
#  '처리',
#  '및',
#  '답변',
#  '내용을',
#  '기재하여',
#  '신고인에게',
#  '통보해',
#  '주시기',
#  '바랍니다.',
#  '-',
#  "'수용'처리는",
#  '과태료',
#  '부과를',
#  '의미합니다.(통계,',
#  '사후관리',
#  '등에',
#  '활용)',
#  '-',
#  '과태료가',
#  '미부과된',
#  '경우',
#  "'일부수용'(계도",
#  '등)',
#  '또는',
#  "'불수용'",
#  '으로',
#  '처리하여',
#  '주시기',
#  '바랍니다.',
#  '-',
#  '신고인의',
#  '개인정보가',
#  '노출되지',
#  '않도록',
#  '각별히',
#  '유의하시기',
#  '바라며,',
#  '답변',
#  '내용은',
#  '신고인에게',
#  '문자로',
#  '발송됩니다."',
#  '횡단보도',
#  '불법',
#  '주차입니다.',
#  '매일',
#  '매시간',
#  '여기에',
#  '주차해',
#  '놓습니다.',
#  '교차로',
#  '모퉁이',
#  '불법',
#  '주정차',
#  '신고입니다.',
#  '횡단보도에',
#  '주차되어있어서',
#  '신고합니다.',
#  '서창',
# ...

# %%
counts = Counter(sentences_tag)
finallist = counts.most_common(10000000000000000000)
# counts = dict(counts)
# pyplot.xticks(range(len(counts)),counts)
# pyplot.bar(range(len(counts.values())),counts.values,align='center')
# pyplot.xlabel('주요단어')
# pyplot.ylabel('출현빈도')
# pyplot.title('주요 단어 별 출현 빈도 분석')
# pyplot.show()

# %%
finallist = counts.most_common(10000000000000000000)

# %%
# list_of_tuples = [('Apples', '=', 10), ('Oranges', '<', 20)]
f = open('commonword.txt', 'w',encoding = 'UTF-8')
for t in finallist:
    line = ' '.join(str(x) for x in t)
    f.write(line + '\n')
f.close()
